# %% [markdown]
# <a href="https://colab.research.google.com/github/cxmedeiros/MetodosNumericos/blob/main/P2_Metodos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise e Projeção do Impacto das festividades Juninas de 2022 para o avanço do Coronavírus no estado de Pernambuco** 🔍

# %% [markdown]
# Alunos 📚:
#
# Breno Mendes de Melo Uchôa Cavalcanti (bmmuc@cin.ufpe.br)
#
# Camila Xavier de Medeiros (cxm@cin.ufpe.br)
#
# Gabriel Lopes de Souza (gls6@cin.ufpe.br)
#
# Mario da Mota Limeira Neto (mmln@cin.ufpe.br)

# %% [markdown]
# # **Resumo**📓

# %% [markdown]
# Neste projeto, analisaremos os dados do Covid 19, no estado de Pernambuco durante o São João de 2022, com foco em entender, visualizar e modelar o impacto que essa festa trouxe para os aumentos dos casos. Com esse intúito, utilizaremos ferramentas de processamento e visualização de dados para analizar como os casos mudaram durante o periodo antes, durante e depois do São João.
#
# Além disso, utilizaremos os modelos matemático *SIDR* (S: pessoas suscetíveis a pegar a doença, I: pessoas infectadas pelo vírus, D: Pessoas que morreram devido ao vírus, R: pessoas que se recuperaram ou foram imunizadas pela vacina), *SIR* (S: pessoas suscetíveis a pegar a doença. I: pessoas infectadas pelo vírus, R: pessoas que se recuperaram ou foram imunizadas pela vacina) e *SIER* (S: pessoas suscetíveis a pegar a doença. I: pessoas infectadas pelo vírus, E: Taxa de exposição do virus, R: pessoas que se recuperaram ou foram imunizadas pela vacina) que se propõem a descrever epidemias, a fim de compararmos os resultados com a realidade e entendermos qual desses modelos é o melhor para prever possíveis aumentos de casos de covid-19 durante eventos de grande aglomeração social.

# %% [markdown]
# # **Introdução** 📘

# %% [markdown]
#   O surto de Covid-19 começou no final de 2019, quando o Coronavírus foi
# descoberto como o agente causador da epidemia em Wuhan, na China. Ainda com o final desse ano, ocorreram também as festividades do Ano Novo Chinês. Esse fator foi um catalisador na ploriferação do vírus para outras províncias nas terras chinesas. A disseminação do vírus foi rápida e em pouco tempo já se registravam os primeiros casos em países europeus. Logo depois, o Coronavírus já se fazia presente no Brasil, e Pernambuco teve seu primeiro caso registrado por meio de um viajante infectado vindo da Europa.

# %% [markdown]
# A COVID-19 é uma doença altamente infecciosa causada pelo coronavírus SARS-CoV-2 e pode variar de casos assintomáticos e manifestações clínicas leves, até quadros moderados, graves e críticos, sendo necessária atenção especial aos sinais e sintomas que indicam piora do quadro clínico que exijam a hospitalização do paciente. De forma geral, os casos podem ser classificados em:
# * **Caso assintomático**: Caracterizado por teste laboratorial positivo para covid-19 e ausência de sintomas.
# * **Caso leve:** Caracterizado a partir da presença de sintomas não específicos, como tosse, dor de garganta ou coriza, seguido ou não de anosmia, ageusia, diarreia, dor abdominal, febre, calafrios, mialgia, fadiga e/ou cefaleia.
# * **Caso moderado:** Os sintomas mais frequentes podem incluir desde sinais leves da doença, como tosse persistente e febre persistente diária, até sinais de piora progressiva de outro sintoma relacionado à covid-19 (adinamia, prostração, hiporexia, diarreia), além da presença de pneumonia sem sinais ou sintomas de gravidade.
# * **Caso grave:** Considera-se a Síndrome Respiratória Aguda Grave. Para crianças, os principais sintomas incluem taquipneia, hipoxemia, desconforto respiratório, alteração da consciência, desidratação, dificuldade para se alimentar, lesão miocárdica, elevação de enzimas hepáticas, disfunção da coagulação, rabdomiólise, cianose central ou SpO2 <90-92% em repouso e ar ambiente, letargia, convulsões, dificuldade de alimentação/recusa alimentar.
#
# **Como ele é transmitido:** De acordo com as evidências mais atuais, o SARS-CoV-2, da mesma forma que outros vírus respiratórios, é transmitido principalmente por três modos: contato, gotículas ou por aerossol. Ou seja, pode ser transmitido durante um aperto de mão seguido do toque nos olhos, nariz ou boca, ou com objetos e superfícies contaminados. Além disso, também pode ocorrer a transmissão por meio da exposição a gotículas respiratórias expelidas, contendo vírus, por uma pessoa infectada quando ela tosse ou espirra, e também, por meio de gotículas respiratórias menores (aerossóis) contendo o vírus e que podem permanecer suspensas no ar por períodos mais longos (geralmente horas).

# %% [markdown]
# **Como se prevenir do COVID-19:**
# * *Distanciamento social.* Limitar o contato próximo entre pessoas infectadas e outras pessoas é importante para reduzir as chances de transmissão do SARS-CoV-2. Trata-se de uma estratégia importante quando há indivíduos já infectados, mas ainda assintomáticos ou oligossintomáticos, que não se sabem portadores da doença e não estão em isolamento.
# * *Higienização das mãos.* É a medida isolada mais efetiva na redução da disseminação de doenças de transmissão respiratória. As evidências atuais indicam que o vírus causador da covid-19 é transmitido por meio de gotículas respiratórias ou por contato. A transmissão por contato ocorre quando as mãos contaminadas tocam a mucosa da boca, do nariz ou dos olhos. O vírus também pode ser transferido de uma superfície para outra por meio das mãos contaminadas, o que facilita a transmissão por contato indireto. Consequentemente, a higienização das mãos é extremamente importante para evitar a disseminação do vírus causador da covid-19.
# * *Etiqueta respiratória.* Uma das formas mais importantes de prevenir a disseminação do SARS-CoV-2 é a etiqueta respiratória, a qual consiste num conjunto de medidas que devem ser adotadas para evitar e/ou reduzir a disseminação de pequenas gotículas oriundas do aparelho respiratório, buscando evitar possível contaminação de outras pessoas que estão em um mesmo ambiente. Algumas ações de etiqueta respiratoria são: cobrir nariz e boca com lenço de papel ou com o antebraço, e nunca com as mãos ao tossir ou espirrar, evitar tocar olhos, nariz e boca com as mãos não lavadas e evitar aglomerações, principalmente em espaços fechados.
# * *Uso de máscaras.* O uso de máscara facial, incluindo as de tecido, é fortemente recomendado para toda a população em ambientes coletivos, em especial no transporte público e em eventos e reuniões, como forma de proteção individual, reduzindo o risco potencial de exposição do vírus especialmente de indivíduos assintomáticos. A pessoa deve ajustar a máscara confortavelmente pelas laterais do rosto, e certificar-se que consegue respirar normalmente. As máscaras não devem ser colocadas em volta do pescoço ou na testa, e ao tocá-la, deve-se lavar as mãos com água e sabão ou álcool em gel 70% para desinfecção. Para pessoas sintomáticas recomenda-se o uso de máscaras cirúrgicas como controle da fonte.
#
# Ademais, o MS (Ministério da Saúde) recomenda ainda a vacinação contra a covid-19 de todos os grupos conforme o Plano Nacional de Operacionalização da Vacinação contra a Covid-19. Estas medidas devem ser utilizadas de forma integrada, a fim de controlar a transmissão do SARS-CoV-2.

# %% [markdown]
# Vale ressaltar que, o início da pandemia evidenciou para o mundo as fragilidades do ser humano, que precisou unir esforços para tentar conter o avanço de um vírus de rápida disseminação e evitar que a doença devastasse ainda mais vidas, sistemas de saúde e economias mundiais. Dessa forma, foi necessário um trabalho conjunto de pesquisadores e especialistas com o objetivo de entender melhor o comportamento do “novo” vírus e suas variantes a fim de entregar uma solução para a sociedade, que se encontrava de mãos atadas naquele momento.

# %% [markdown]
# Diante desse cenário, é importante lembrar que modelos matemáticos epidemiológicos foram bastante utilizados para prever e analisar eventuais situações que pudessem ocorrer ao longo da pandemia, como monitorar o avanço da doença ou até mesmo prever picos de infecção. Existem alguns modelos já estabelecidos na comunidade que funcionam dessa maneira e com esse intuito. Um modelo bem conhecido é o *SIR*, que considera Suscetíveis, Infectados e Recuperados como únicas fases da doença e a partir dessas variáveis descreve a propagação do vírus.

# %% [markdown]
# Apesar do *SIR* ser muito comum, neste projeto utilizaremos outras variações desse modelo, que são o *SEIR* e o *SIDR*, considerando a vacinação constante. Ambos os modelos também têm a finalidade de mostrar a ploriferação da doença, contudo considerando mais variáveis como fases da infecção. O *SEIR* consiste em adicionar o estágio de Expostos, no qual o indivíduo já foi infectado mas ainda não é um transmissor para outros indivíduos. Já o *SIDR* adiciona o estágio Death, para considerar as mortes derivadas da infecção. Esses modelos levam em conta uma amostra homogênea, na qual todos os indivíduos da população possuem a mesma suscetibilidade à doença.

# %% [markdown]
# Quanto mais situações o modelo considerar em sua projeção mais próximo da realidade chega o resultado. Entretanto, sabemos que há diversas situações possíveis que ocorrem/ocorreram nesses tempos de pandemia e que não são consideradas pelos modelos aqui apresentados, podendo gerar resultados não esperados.

# %% [markdown]
# # **Objetivos** 🎯

# %% [markdown]
# O foco ao longo desse projeto será dado na análise de dados da pandemia de Covid-19 em Pernambuco, mais especificamente nos períodos pré e pós a realização do São João de 2022.

# %% [markdown]
# A finalidade dessa restrição na linha do tempo durante a pandemia é analisar, comparar e entender se houve alguma evolução dos casos de coronavírus na população em razão da realização das festas juninas no estado, mesmo diante da vigência da vacinação.

# %% [markdown]
# Para podermos interpretar os modelos e o comportamento do vírus vamos explorar graficamente os resultados em alguns cenários e comparar os três modelos a fim de demonstrar a fidedignidade com os resultados reais e a forma como cada modelo executa os dados a depender das variáveis utilizadas, concluindo qual será o melhor modelo para essa situação analisada.

# %% [markdown]
# # **Mapa mental** ☺

# %% [markdown]
# ![Anlise_e_Projeo_do_impacto_das_festividades_juninas_de_2022_para_o_avano_do_Coronavirus_no_estado_de_Pernambuco_.png](data:image/png;base64,...)

# %% [markdown]
# *link do mapa mental:* https://coggle.it/diagram/ZAoJNkKapKjeCAtt/t/an%C3%A1lise-e-proje%C3%A7%C3%A3o-do-do-coronavirus-no-estado-de-pernambuco/86c6f5d2c715c625e42b0eb3d98096fa53aa7d7ad22a9de71f65e583dad8a4f8

# %% [markdown]
# #**(SIR)** 🦠

# %% [markdown]
# Primeiramente, vamos explicar o modelo epidemiológico SIR, proposto por Kermack e McKendrick em 1927, é a base dos modelos epidemiológicos mais sofisticados que conhecemos hoje. Ele é baseado na hipótese de que o indivíduo de uma determinada população, onde ocorre uma epidemia, passa por diferentes estágios de suscetibilidade à infecção.

# %% [markdown]
# O sistema SIR é fundamentado em três grupos:

# %% [markdown]
# - **S(t):** pessoas suscetíveis a pegar a doença.
# - **I(t):** pessoas infectadas pelo vírus.
# - **R(t):** pessoas que se recuperaram ou foram imunizadas pela vacina.

# %% [markdown]
# Sob a premissa de uma população invariável, onde a taxa de propagação da doença é denotada por  β  e a taxa média de recuperação é representada por  γ , podemos expressar as equações da seguinte forma:
#
# \begin{align}
# \frac{{\rm d}S}{{\rm d}t} & = -\beta S I/N\\
# \frac{{\rm d}I}{{\rm d}t} & = \beta S I/N- \gamma I\\
# \frac{{\rm d}R}{{\rm d}t} & = \gamma I\\
# \end{align}

# %% [markdown]
# Onde 1 / γ é o período médio de tempo durante o qual um indivíduo infectado pode transmitir o vírus.

# %% [markdown]
# Podemos observar que a soma total dS/dt + dI/dt + dR/dt é igual a zero, já que a população é considerada constante. Além disso, analisando cada termo, podemos notar que a taxa de variação dos indivíduos suscetíveis depende do contato do grupo S com o grupo I, o que é relevante para as análises futuras.

# %% [markdown]
# #### Para o valor de γ:

# %% [markdown]
# β e γ são valores utilizados tanto para o modelo SIR como para o SIDR. O cálculo do valor pra γ é o seguinte:
#
# γ = 1/dias infectados
#
# γ = 1/15

# %% [markdown]
# #### Cálculo de β:

# %% [markdown]
# O valor de β foi baseado em um site que está presente nas referências, com o valor de 0.5.

# %% [markdown]
# #**(SIER)** 🦠

# %% [markdown]
# Este nada mais é do que uma variação do modelo SIR, que leva em consideração mais variáveis para aproximar mais o resultado da realidade.
#
# Antes de aplicarmos o modelo proposto, iremos mostrar os resultados do modelo SEIR, para, no fim, compará-lo com o SIDR.

# %% [markdown]
# Para o modelo SEIR, precisamos adicionar uma nova equação para o grupo E.
#
# **Expostos E (t):** pessoas que estão expostas ao vírus.
#
#  Assumindo que δ é o tempo que um indivíduo infectado leva para se tornar infeccioso, as equações são:

# %% [markdown]
# \begin{align}
# \frac{{\rm d}S}{{\rm d}t} & = -\beta S (I+qE)/N\\
# \frac{{\rm d}E}{{\rm d}t} & = \beta S (I+qE)/N- E/\delta \\
# \frac{{\rm d}I}{{\rm d}t} & = E/\delta-\gamma I\\
# \frac{{\rm d}R}{{\rm d}t} & = \gamma I\\
# \end{align}

# %% [markdown]
# Observe que o grupo E aparece na equação do grupo S, pois um indivíduo exposto pode espalhar o vírus sem demonstrar sintomas. A constante `q` é usada para contabilizar a menor probabilidade de um indivíduo exposto infectar outra pessoa, comparado à probabilidade de um indivíduo infeccioso fazer o mesmo.
#
# Para aprimorar o modelo SEIR, é necessário acrescentar novas variáveis, como nosso objetivo é analisar o impacto do SJ no número de pessoas com covid, iremos adicionar variáveis relacionadas a taxa de vacinacao, e iremos mudar a premissa de população constante.

# %% [markdown]
# # **(SIDR)** 🦠

# %% [markdown]
# No modelo SIDR iremos adicionar as variáveis de óbitos e vacinação.
#
# Iremos nos basear em um modelo amplamente conhecido chamado de *SIDR*.
# Para discretizar esse problema, vamos reutilizar alguns temos do tópico anterior e modificálos.
#
# Como já era esperado, a população não será constante aqui, ela será variável em virtude do número de óbitos que a covid-19 causa. Para facilitar o entendimento, a população será dividida da seguinte forma:
#
# - **S(t):** pessoas suscetíveis a pegar a doenca.
# - **I(t):** pessoas infectadas pelo vírus.
# - **D(t):** Pessoas que morreram devido ao virus.
# - **R(t):** pessoas que se recuperaram ou foram imunizadas pela vacina.

# %% [markdown]
# Para fazer a modelagem, utilizaremos os seguintes parâmetros:
#
# ψ →	Representa a taxa de vacinação e a eficácia de vacina
#
# β →	Representa a taxa de infecção do vírus
#
# γ →	Representa a taxa de recuperação
#
# ρ →	Representa a taxa de mortalidade em decorrência da doença
#
# Φ →	Representa a taxa de imunização

# %% [markdown]
# A equação dS(t)/dt descreve a taxa de variação ao longo do tempo do grupo de indivíduos suscetíveis à infecção, levando em consideração a taxa de transmissão β, o número de indivíduos infectados I(t), a taxa de recuperação γ, a taxa de mortalidade ρ, a taxa de imunização Φ e a taxa de vacinação e eficácia da vacina ψ.

# %% [markdown]
# \begin{align}
#  \frac {dS(t)} {dt} = - β.S(t).I(t)
# \end{align}
# \begin{align}
# \frac {dI(t)} {dt} = β.S(t).I(t) - (γ/1-ρ).I(t)
# \end{align}
# \begin{align}
# \frac {dD(t)} {dt} = (ρ/1-ρ).γ.I(t)
# \end{align}
# \begin{align}
# \frac {dR(t)} {dt} = γ.I(t)
# \end{align}

# %% [markdown]
# De maneira análoga, ao modelo SIR, teremos: *N = S(t) + I(t) + D(t) + R(t)*

# %% [markdown]
# # **Visualizando os dados** 📊

# %%
import pandas as pd
import numpy as np
import plotly.offline as py
import plotly.graph_objs as go

# %%
from google.colab import drive
# drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
covid_pe = pd.read_csv('./covid-data.csv')
covid_pe.head(3)
# Out:
#   dt_referencia  dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 0    2020-04-03             NaN          176      14      0.080           23
# 1    2020-04-04             NaN          201      21      0.104           25
# 2    2020-04-05             NaN          223      30      0.134           25
#
#    tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  uti  \
# 0           0.131          87          0.569          34          0.222   18
# 1           0.124          87          0.494          49          0.278   19
# 2           0.112         101          0.510          44          0.222   23
#
#    tx_uti  testes_novos  testes_acumulados  tx_testes  leitos_uti  tx_oc_uti  \
# 0   0.102             0                  0          0           0        0.0
# 1   0.094             0                  0          0           0        0.0
# 2   0.103             0                  0          0           0        0.0
#
#    leitos_enf  tc_oc_enf
# ...

# %%
covid_pe = covid_pe.fillna('0') 
covid_pe.head(3)
# Out:
#   dt_referencia dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 0    2020-04-03              0          176      14      0.080           23
# 1    2020-04-04              0          201      21      0.104           25
# 2    2020-04-05              0          223      30      0.134           25
#
#    tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  uti  \
# 0           0.131          87          0.569          34          0.222   18
# 1           0.124          87          0.494          49          0.278   19
# 2           0.112         101          0.510          44          0.222   23
#
#    tx_uti  testes_novos  testes_acumulados  tx_testes  leitos_uti  tx_oc_uti  \
# 0   0.102             0                  0          0           0        0.0
# 1   0.094             0                  0          0           0        0.0
# 2   0.103             0                  0          0           0        0.0
#
#    leitos_enf  tc_oc_enf
# ...

# %%
covid_pe['dt_referencia'] = pd.to_datetime(covid_pe['dt_referencia'])

# %%
print(covid_pe['dt_referencia'].min())
print(covid_pe['dt_referencia'].max())
# Out:
# 2020-04-03 00:00:00
# 2022-12-01 00:00:00

# %% [markdown]
# ### 📊 Visualizando a evolução de casos no período antes do São João

# %%
covid_antes_sj = covid_pe[['dt_referencia', 'confirmados', 'obitos']]
covid_antes_sj.head(3)
# Out:
#   dt_referencia  confirmados  obitos
# 0    2020-04-03          176      14
# 1    2020-04-04          201      21
# 2    2020-04-05          223      30

# %%
periodo  = (covid_antes_sj['dt_referencia'] >= '2022-04-12') & (covid_antes_sj['dt_referencia'] <= '2022-06-12')
covid_antes_sj = covid_antes_sj[periodo]

# %%
trace = go.Line(x = covid_antes_sj['dt_referencia'],
                   y = covid_antes_sj['confirmados'],)

layout = go.Layout(title='Covid 19 em Pernambuco antes do São João 2022',
                   yaxis={'title':'Casos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace = go.Line(x = covid_antes_sj['dt_referencia'],
                   y = covid_antes_sj['obitos'],)

layout = go.Layout(title='Mortes por Covid 19 em Pernambuco antes do São João 2022',
                   yaxis={'title':'Óbitos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 📊 Visualizando a evolução de casos no período depois do São João

# %%
covid_depois_sj = covid_pe[['dt_referencia', 'confirmados','obitos']]
covid_depois_sj.head(3)
# Out:
#   dt_referencia  confirmados  obitos
# 0    2020-04-03          176      14
# 1    2020-04-04          201      21
# 2    2020-04-05          223      30

# %%
periodo  = (covid_depois_sj['dt_referencia'] >= '2022-06-12') & (covid_depois_sj['dt_referencia'] <= '2022-08-12')
covid_depois_sj = covid_depois_sj[periodo]

# %%
trace = go.Line(x = covid_depois_sj['dt_referencia'],
                   y = covid_depois_sj['confirmados'],)

layout = go.Layout(title='Covid 19 em Pernambuco depois do São João de 2022',
                   yaxis={'title':'Casos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace = go.Line(x = covid_depois_sj['dt_referencia'],
                   y = covid_depois_sj['confirmados'],)

layout = go.Layout(title='Mortes por Covid 19 em Pernambuco depois do São João 2022',
                   yaxis={'title':'Óbitos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 📊 Visualizando a evolução de casos no período antes e depois do São João

# %%
covid_antes_depois_sj = covid_pe[['dt_referencia', 'confirmados','obitos', 'recuperados']]
covid_antes_depois_sj.head(3)
# Out:
#   dt_referencia  confirmados  obitos  recuperados
# 0    2020-04-03          176      14           23
# 1    2020-04-04          201      21           25
# 2    2020-04-05          223      30           25

# %%
periodo  = (covid_antes_depois_sj['dt_referencia'] >= '2022-04-12') & (covid_antes_depois_sj['dt_referencia'] <= '2022-08-12')
covid_antes_depois_sj = covid_antes_depois_sj[periodo]

# %%
trace = go.Line(x = covid_antes_depois_sj['dt_referencia'],
                   y = covid_antes_depois_sj['confirmados'],)

layout = go.Layout(title='Covid 19 em Pernambuco antes e depois do São João de 2022',
                   yaxis={'title':'Casos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace = go.Line(x = covid_antes_depois_sj['dt_referencia'],
                   y = covid_antes_depois_sj['obitos'],)

layout = go.Layout(title='Mortes por Covid 19 em Pernambuco antes e depois do São João de 2022',
                   yaxis={'title':'Óbitos acumulados'},
                   xaxis={'title': 'Tempo'}, height=600, width=800)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
covid_antes_depois_sj.head()
# Out:
#     dt_referencia  confirmados  obitos  recuperados
# 739    2022-04-12       911329   21506       766013
# 740    2022-04-13       912512   21515       767068
# 741    2022-04-14       913502   21525       768046
# 742    2022-04-15       913786   21531       768087
# 743    2022-04-16       913960   21536       770999

# %% [markdown]
# Podemos observar nesses gráficos que com o feriado do São João tivemos um aumento significativo na quantidade de casos, isso se deve ao fato das pessoas sairem mais, ficarem mais aglomeradas e também se precaverem menos nos locais. Contudo, a quantidade de óbitos não teve uma crescente tão grande, porém, antes do São João ele apresentava um início de queda, mas após ele, voltou a aumentar.

# %% [markdown]
# # Aplicando Modelo **SIR**🦠

# %%
import numpy as np
from scipy.integrate import odeint
import plotly.express as px
import pandas as pd

# %%
N = 911329 + 21506 + 766013 # confirmados + obitos + recuperados de 12 de abril de 2022

# Numero Inicial de Infectados, Removidos e Mortos
I0 = int(911329 / N * 100)

R0 = int(766013 / N * 100)
print(I0, R0)
# Todas as outras pessoas são suscetíveis, inicialmente
S0 = N - I0 - R0

# Taxa de Infecção
# Taxa de Recuperação, 1/dias infectados(média de 15)
gamma = 1/15
beta = 0.5 # baseada na referência
print(gamma)
print(beta)
# Dias Decorridos
t = np.linspace(0, 120, 120) 

def calcSIR(x, t):
  s,i,r = x
  dt = np.zeros(3)
  
  dt[0] = -beta * s*i/N 
  dt[1] = (beta*s*i/N) - gamma*i
  dt[2] = gamma*i

  return dt
dados = [S0, I0, R0]
x = odeint(calcSIR, dados, t)
s = x[:,0]
i = x[:,1]
r = x[:,2]
results = {'time':t, 'sucetiveis':s/N, 'infecciosos':i/N, 'recuperados':r/N}
result = pd.DataFrame.from_dict(results)

#PLOTANDO O GRAFICO
fig = px.line(result, x = 'time', y=['sucetiveis', 'infecciosos', 'recuperados'])
fig.update_layout(xaxis_title = 'Time in days', yaxis_title = 'Percent', title = 'SIR aplicated on Pernambuco Covid-19 Data in 2021')
fig.show()
# Out:
# 53 45
# 0.06666666666666667
# 0.5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig0 = go.Figure()
df_previsao = covid_pe[['dt_referencia', 'confirmados', 'recuperados', 'obitos']]

periodo_previsao = (df_previsao['dt_referencia'] >= '2022-04-12') & (df_previsao['dt_referencia'] <= '2022-08-12')
df_previsao = df_previsao[periodo_previsao]

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (i + r), name = 'SIR'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = df_previsao['confirmados'] + df_previsao['recuperados'] , name = 'Realidade'))

fig0.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Aplicando Modelo **SIER**🦠

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from scipy.integrate import odeint

N = 911329 + 21506 + 766013 # confirmados + obitos + recuperados de 12 de abril de 2022

# Numero Inicial de Infectados, Removidos e Mortos
I0 = int(911329 / N * 100)

R0 = int(766013 / N * 100)
print(I0, R0)

# Todas as outras pessoas são suscetíveis, inicialmente

S0 = N - I0 - R0

# Taxa de Infecção
# Taxa de Recuperação, 1/dias infectados(média de 15)
gamma = 1/15
beta = 0.5
delta = 5  # período de incubação
q = 0.1  # proporção de contatos infecciosos para expostos

E0 = S0 * q # número inicial de expostos

t = np.linspace(0, 120, 120)

def calcSIER(x, t):
    s, e, i, r = x
    dsdt = -beta * s * (i + q * e) / N
    dedt = beta * s * (i + q * e) / N - e / delta
    didt = e / delta - gamma * i
    drdt = gamma * i
    return [dsdt, dedt, didt, drdt]

dados = [S0, E0, I0, R0]
x = odeint(calcSIER, dados, t)
s = x[:, 0]
e = x[:, 1]
i = x[:, 2]
r = x[:, 3]

results = {'time': t, 'susceptible': s/N, 'exposed': e/N, 'infectious': i/N, 'recovered': r/N}
result = pd.DataFrame.from_dict(results)

fig = px.line(result, x='time', y=['susceptible', 'exposed', 'infectious', 'recovered'])
fig.update_layout(xaxis_title='Time (days)', yaxis_title='Fraction of population', title='SIER Model Simulation')
fig.show()
# Out:
# 53 45
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig0 = go.Figure()
df_previsao = covid_pe[['dt_referencia', 'confirmados', 'recuperados', 'obitos']]

periodo_previsao = (df_previsao['dt_referencia'] >= '2022-04-12') & (df_previsao['dt_referencia'] <= '2022-08-12')
df_previsao = df_previsao[periodo_previsao]

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (i + r), name = 'SIER'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = df_previsao['confirmados'] + df_previsao['recuperados'] , name = 'Realidade'))

fig0.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Aplicando Modelo **SIDR**🦠

# %%
astrazeneca =  5044420 / 17206490
coronavac = 4232840 / 17206490
janssen = 305510 / 17206490
pfizer = 7623720 / 17206490

astrazeneca + coronavac + janssen + pfizer
# Out:
# 1.0

# %% [markdown]
# A fim de determinar a eficácia média, vamos realizar uma média ponderada levando em conta o número total de doses administradas para cada tipo de vacina e as suas respectivas taxas de eficácia.

# %%
eficacia = astrazeneca * 100 * 0.76 + coronavac * 100 * 0.65 + janssen * 100 * 0.66 + pfizer * 100 * 0.84
round(eficacia)
# Out:
# 77

# %% [markdown]
# encontramos uma eficacia de 77%

# %%
covid_pe.tail(1)
# Out:
#     dt_referencia dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 972    2022-12-01              0      1089123   22482      0.021       929171
#
#      tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  \
# 972           0.853           0            0.0           0            0.0
#
#      uti  tx_uti  testes_novos  testes_acumulados  tx_testes  leitos_uti  \
# 972    0     0.0         11753            4901163     510538         581
#
#      tx_oc_uti  leitos_enf  tc_oc_enf
# 972       0.79         507       0.64

# %%
covid_pe[covid_pe['dt_referencia'] == '2022-04-12']
# Out:
#     dt_referencia dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 739    2022-04-12              0       911329   21506      0.024       766013
#
#      tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  \
# 739           0.841         296          0.002         845          0.006
#
#      uti  tx_uti  testes_novos  testes_acumulados  tx_testes  leitos_uti  \
# 739  626   0.001          5526            3827153     398662         789
#
#      tx_oc_uti  leitos_enf  tc_oc_enf
# 739       0.54         889       0.35

# %%
covid_pe[covid_pe['dt_referencia'] == '2022-08-12']
# Out:
#     dt_referencia dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 861    2022-08-12              0      1040001   22111      0.021       886309
#
#      tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  \
# 861           0.852          45            0.0         739          0.005
#
#      uti  tx_uti  testes_novos  testes_acumulados  tx_testes  leitos_uti  \
# 861  615   0.001          4570            4521910     471032         615
#
#      tx_oc_uti  leitos_enf  tc_oc_enf
# 861       0.72         555        0.5

# %% [markdown]
# Utilizaremos a taxa de mortalidade (casos confirmados / óbitos) da última atualização do dataset = 0.021

# %%
df_previsao = covid_pe[['dt_referencia', 'confirmados', 'recuperados', 'obitos']]

periodo_previsao = (df_previsao['dt_referencia'] >= '2022-04-12') & (df_previsao['dt_referencia'] <= '2022-08-12')
df_previsao = df_previsao[periodo_previsao]

# %%
df_previsao.head()
# Out:
#     dt_referencia  confirmados  recuperados  obitos
# 739    2022-04-12       911329       766013   21506
# 740    2022-04-13       912512       767068   21515
# 741    2022-04-14       913502       768046   21525
# 742    2022-04-15       913786       768087   21531
# 743    2022-04-16       913960       770999   21536

# %%
N = 911329 + 21506 + 766013
I0 = int(911329 / N * 100)

R0 = int(21506 / N * 100)
# Numero Inicial de Infectados, Removidos e Mortos
I0 = 911329 
D0 = 21506
# R0 = 766013 - D0

# Todas as outras pessoas são suscetíveis, inicialmente
S0 = N - I0 - R0 - D0

# Taxa de Vacinação e Eficácia da Vacina

v = 0.77 * (77227/N)

# Taxa de Infecção
beta = 0.5

# Taxa de Recuperação
gamma = 1./15

# Taxa de Mortalidade
ro = 0.021

# Taxa de imunização
phi = 0.85

# Dias Decorridos
t = np.linspace(0, 120, 120)

# %% [markdown]
# O cálculo para a taxa de vacinação (ψ) foi feito com os dados disponibilizados, usou-se o número do total de vacinados e um intervalo de tempo de vacinação de 120 dias (12/04/2022 até 12/08/2022). Com isso, a taxa foi o total de vacinados dividido pelos 120 dias.
#
# Já para a taxa de imunização (Φ) usada nos modelos SIDR, que é a chance que uma pessoa tem de se tornar imune após se recuperar da doença, foi obtida através do artigo da World Health Organization.
#
# Φ = 0.85
#
# Taxa de mortalidade(ρ): são utilizados os dados da última atualização do Dataset “Covid 19 em dados” da Secretaria da Saúde de Pernambuco”
#
# ρ = 0.021

# %%
def deriv(y, t, N, beta, gamma, ro, v, phi):

  S, I, D, R = y

  dSdt = (- beta * S * I)
  dIdt = (beta * S * I) - (gamma / (1 - ro)) * I 
  dDdt = (ro / (1 - ro)) * gamma * I 
  dRdt = gamma * I

  return dSdt, dIdt, dDdt, dRdt


# Condições Iniciais
y0 = S0, I0, D0, R0

ret = odeint(deriv, y0, t, args=(N, beta, gamma, ro, v, phi))
S, I, D, R = ret.T

# %%
fig0 = go.Figure()

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (R/N), name = 'Recuperados'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (I/N), name = 'Infectados'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (D/N), name = 'Mortos'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (S/N), name = 'Suscetíveis'))

fig0.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def deriv(y, t, N, beta, gamma, ro, v, phi):

  S, I, D, R = y

  dSdt = (- beta * S * I)
  dIdt = (beta * S * I) - (gamma / (1 - ro)) * I 
  dDdt = (ro / (1 - ro)) * gamma * I 
  dRdt = gamma * I

  return dSdt, dIdt, dDdt, dRdt


# Condições Iniciais
y0 = S0, I0, D0, R0

ret = odeint(deriv, y0, t, args=(N, beta, gamma, ro, v, phi))
S, I, D, R = ret.T

# %%
fig0 = go.Figure()

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = (I + R), name = 'SIDR'))

fig0.add_trace(go.Line(x = df_previsao['dt_referencia'],
              y = df_previsao['confirmados'] + df_previsao['recuperados'] , name = 'Realidade'))

fig0.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Resultados** 👀

# %% [markdown]
# Considerando apenas o modelo SIDR, é necessário aprimorar as equações para que possam ser mais adequadas para descrever a situação atual, uma vez que houve uma grande divergência entre os resultados obtidos pelo modelo e a realidade.
#
# Na primeira etapa do projeto, levantamos alguns questionamentos que serão abordados agora:
#
# Será que diferentes modelos epidemiológicos podem ser igualmente eficazes para descrever uma epidemia real?
# Apesar de todas as suas limitações, acreditamos que sim, já que esses modelos conseguem ser uma aproximação "grosseira" de um fenômeno real.
#
# Os resultados obtidos pelos modelos são compatíveis com a realidade?
# No caso do modelo SIDR que propusemos, os resultados não coincidiram muito bem com os dados reais. Temos algumas hipóteses sobre o comportamento de certas variáveis e como elas estão sendo inseridas nas nossas equações.
#
# Será que as festividades, a diminuição do isolamento social e das medidas sanitárias no meio de 2022 foram responsáveis pelo aumento no número de casos de Covid-19 em Pernambuco?
# Sim, esses fatores contribuíram para o aumento na transmissão do Covid-19. No entanto, não houve um aumento na quantidade de óbitos, apenas uma estabilização. Além disso, a vacinação foi fundamental para evitar um aumento ainda maior no número de casos.

# %% [markdown]
# ### **Conclusão** ✅

# %% [markdown]
# Nós escolhemos o modelo SIDR por conta da sua eficiência. Em termos matemáticos, o modelo á relativamente simples, se comparado a outros modelos da área que não utilizamos no projeto, pois o mesmo trata-se de um sistema de equações diferenciais. Em termos de eficácia, esse modelo já foi utilizado para modelar diversas doenças virais infecciosas no passado, mostrando-se altamente eficiente na estimação do andamento da epidemia na população, quando suas condições de aplicabilidade são satisfeitas.
#
# Contudo, o modela SIDR não atendeu o nosso propósito de prever o aumento dos casos pós São João. Com isso, considerando as limitações do modelo SIDR e a falta de precisão em relação à realidade da epidemia em estudo, nosso projeto testou outros dois modelos epidemiológicos apresentados no código que são mais simples, o SIR e o SIER. O SIR mesmo sendo um modelo mais simples dentre os três, chegou próximo dos dados reais. Contudo, o SIER foi o que mais se assemelhou á realidade. Vale ressaltar que ele possui a variável "E(t): exposição" que os outros modelos não apresentam. É importante destacar que cada modelo tem suas vantagens e limitações, e escolher o mais apropriado dependerá da situação específica analisada e dos dados disponíveis.
#
# Nosso objetivo é obter um modelo epidemiológico mais preciso e confiável que possa ser utilizado para orientar as políticas de saúde pública e contribuir para a prevenção e controle de doenças infecciosas. Para alcançar esse objetivo, estamos comprometidos em revisar constantemente nossos parâmetros e equações, e implementar novas abordagens e técnicas conforme necessário.

# %% [markdown]
# ##**Referências** 📚

# %% [markdown]
# [1] “Coronavírus Brasil” [Online]. Disponível em: https://covid.saude.gov.br/.
#
# [2] "Equações diferenciais e modelos epidemiológicos" [Online]. Disponível em: https://impa.br/wp-content/uploads/2022/01/33CBM08-eBook.pdf
#
# [3] "Coronavírus — Ministério da Saúde" [Online] Disponível em: https://www.gov.br/saude/pt-br/coronavirus
#
# [4] "Folha informativa sobre COVID-19 - OPAS/OMS | Organização Pan-Americana da Saúde" [Online] Disponível em: https://www.paho.org/pt/covid19
#
# [5] "COVID-19 em Dados" [Online] Disponível em: https://dados.seplag.pe.gov.br/apps/corona.html
#
#
# [6] "História - Festas juninas" [Online] Disponível em:https://www.terra.com.br/diversao/historia-festas-juninas,72bd421a2df4a310VgnCLD200000bbcceb0aRCRD.html
#
# [7] "A evolução epidêmica do COVID-19 – Modelo SIR" [Online] Disponível em: https://wp.ufpel.edu.br/fentransporte/2020/04/09/a-evolucao-epidemica-do-covid-19-modelo-sir/
#
#
# [8] "Modelagem Dinâmica da Covid-19 com Aplicação a Algumas Cidades Brasileiras"[Online] Disponível em: https://imef.furg.br/images/stories/documentos/2020/artigo2.pdf
#
# [9]"Mathematical modelling of the second wave of COVID-19 infections using deterministic and stochastic SIDR models - PMC" [Online]  Disponível em: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8261056/
#
# [10] "ENTENDA O QUE É TAXA DE TRANSMISSÃO DA COVID-19!" [Online] Disponível em: https://coronavirus.saude.mg.gov.br/blog/164-taxa-de-transmissao-covid-19
#
# [11] "Modelagem Matemática para Epidemia de COVID-19 e Estimativa de Casos no Brasil no Curto Prazo" [Online] Disponível em: https://covid19cientifico.ime.eb.br/artigo1.pdf
